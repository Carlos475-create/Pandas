# %%
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
netflix_original = pd.read_csv("/Users/Charlie/Desktop/hackio/da-octubre-24/Modulo2/labs/enunciados/datos/netflix_originals.csv", index_col= 0)

# %%
display(netflix_original)
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 576                       Cuba and the Cameraman            Documentary
# 577                       Dancing with the Birds            Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %%
print(netflix_original.duplicated().sum())
# Out:
# 0

# %%
netflix_title = pd.read_csv("/Users/Charlie/Desktop/hackio/da-octubre-24/Modulo2/labs/enunciados/datos/netflix_titles.csv", index_col= 0)
display(netflix_title)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(netflix_title.duplicated().sum())
# Out:
# 0

# %%
netflix_merge = pd.merge(netflix_original, netflix_title, left_on = "Title", right_on = "title")
print(netflix_merge)
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 508                       Cuba and the Cameraman            Documentary
# 509                       Dancing with the Birds            Documentary
# 510  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 511                      Springsteen on Broadway           One-man show
# 512     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language show_id  \
# ...

# %%
print(f"Tenemos {netflix_merge.shape[0]} filas y {netflix_merge.shape[1]} columnas")
# Out:
# Tenemos 513 filas y 18 columnas

# %%
netflix_merge.pop("title")
# Out:
# 0                                  Enter the Anime
# 1                                      Dark Forces
# 2                                          The App
# 3                                   The Open House
# 4                                      Kaali Khuhi
#                           ...
# 508                         Cuba and the Cameraman
# 509                         Dancing with the Birds
# 510    Winter on Fire: Ukraine's Fight for Freedom
# 511                        Springsteen on Broadway
# 512       David Attenborough: A Life on Our Planet
# Name: title, Length: 513, dtype: object

# %%
netflix_merge.shape[1]
# Out:
# 17

# %% [markdown]
# He eliminado la columna 'title' porque está duplicada

# %%
print(f"Ahora tenemos {netflix_merge.shape[0]} filas y {netflix_merge.shape[1]} columnas")
# Out:
# Ahora tenemos 513 filas y 17 columnas

# %%
print(netflix_merge.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Tenemos 0 duplicados

# %%
netflix_merge.describe(include="O").T
# Out:
#             count unique                                                top  \
# Title         513    513           David Attenborough: A Life on Our Planet
# Genre         513    106                                        Documentary
# Premiere      513    350                                   October 18, 2019
# Language      513     37                                            English
# show_id       513    513                                              s1887
# type          513      1                                              Movie
# title         513    513           David Attenborough: A Life on Our Planet
# director      491    462                                                McG
# cast          422    421                                       Shawn Mendes
# country       499     81                                      United States
# date_added    513    354                                   October 18, 2019
# ...

# %%
netflix_merge.describe().T
# Out:
#               count         mean        std     min     25%     50%     75%  \
# Runtime       513.0    94.674464  26.648121     4.0    87.0    97.0   108.0
# IMDB Score    513.0     6.210916   0.968850     2.5     5.6     6.3     6.9
# release_year  513.0  2018.888889   1.510812  2014.0  2018.0  2019.0  2020.0
#
#                  max
# Runtime        209.0
# IMDB Score       9.0
# release_year  2021.0
